# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd
df = pd.read_csv('vgsales.csv')
df
# Out:
# KeyboardInterrupt

# %%
import pandas as pd

df = pd.read_csv(r'E:\Python\Machine learning\vgsales.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2
#       3 df = pd.read_csv(r'E:\Python\Machine learning\vgsales.csv')
#       4 df.head()
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd
df = pd.read_csv('vgsales.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#       2 df = pd.read_csv('vgsales.csv')
#       3 df.head()
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# if 5>2:
#     print('five is greater than two')

# %%
if 5>2:
    print("five is greater than two")
# Out:
# five is greater than two

# %%
if 5>2:
    print("five is greater than two")
if 2<4:
    print("two is less than four")
# Out:
# five is greater than two
# two is less than four
